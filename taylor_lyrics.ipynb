# %% [markdown]
# # Analyze Taylor Swift Lyrics with Python
#
# ### Try some of these resources for extra help as you work:
#
# * [View the Analyze Taylor Swift Lyrics with Python Cheatsheet](https://www.codecademy.com/learn/case-study-analyze-taylor-swift-lyrics/modules/analyze-taylor-swift-lyrics/cheatsheet)
# * Learn more about analyzing text in [Apply Natural Language Processing with Python](https://www.codecademy.com/learn/paths/natural-language-processing)
#
# [View the solution notebook](./solution.html)
#
# [The original dataset was curated by Jan Llenzl Dagohoy and published on Kaggle](https://www.kaggle.com/datasets/thespacefreak/taylor-swift-song-lyrics-all-albums)

# %%
# %matplotlib inline

import pandas as pd
import string
import seaborn as sns
import matplotlib.pyplot as plt
import collections
import nltk
from nltk.tokenize import word_tokenize
from nltk.sentiment import SentimentIntensityAnalyzer

# %% [markdown]
# ### 1. Load the dataset
#
# After running the first cell to load all necessary libraries, we need to load our dataset.
# * Using pandas, load the dataset taylor_swift_lyrics_2006-2020_all.csv and save it as lyrics.
# * Inspect the first few rows.
# * Use `.info()` to determine how many rows there are, check for missing values, and check the variable types.

# %% [markdown]
# *Note that we added the lyrics from the new Midnights album. If you want to inspect the lyrics from that album, you can find them in the file tree. Click on the Jupyter logo in the upper left corner and you can see all the files.*
#
# *Use "taylor_swift_lyrics_2006-2022_all.csv" in the `pd.read_csv()` function below to also analyze Midnights.*

# %%
# load dataset
lyrics = pd.read_csv("taylor_swift_lyrics_2006-2020_all.csv")

#inspect the first few rows
## YOUR CODE HERE ##
lyrics.head()
# Out:
#                     album_name                  track_title  track_n  \
# 0  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 1  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 2  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 3  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 4  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
#
#                                                lyric  line
# 0                    There's something 'bout the way     1
# 1             The street looks when it's just rained     2
# 2  There's a glow off the pavement, you walk me t...     3
# 3  And you know I wanna ask you to dance right there     4
# 4             In the middle of the parking lot, yeah     5

# %%
#get info about the DataFrame
## YOUR CODE HERE ##
lyrics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8358 entries, 0 to 8357
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   album_name   8358 non-null   object
#  1   track_title  8358 non-null   object
#  2   track_n      8358 non-null   int64
#  3   lyric        8358 non-null   object
#  4   line         8358 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 326.6+ KB

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover in this step? Toggle to check!</i></summary>
#
# The Taylor Swift lyrics dataset consists of comprehensive data on the lyrics from her albums 2020. There are no missing values. We can see the lyric details along the column axis and each lyric along the row axis. We can find the name  of each album, the track, and the line in which the lyric appears. We do not have year associated with this dataset.
#
# </details>

# %% [markdown]
# ### 2. Add essential data
#
# We know that we want to explore her use of terms over years, but this dataset doesn't have years. We can either merge a dataset or manually create a new column. We have created a function for you that fills in the year based on the album name.
#
# * Apply this function to the `lyrics` DataFrame to create a new column.
# * Inspect the first few rows of the DataFrame

# %%
# get a list of all the albums in this collection
## YOUR CODE HERE ##

# %%
# this is a function to map the name of the album to the year it was released
def album_release(row):  
    if row['album_name'] == 'Taylor Swift':
        return '2006'
    elif row['album_name'] == 'Fearless (Taylor’s Version)':
        return '2008'
    elif row['album_name'] == 'Speak Now (Deluxe)':
        return '2010'
    elif row['album_name'] == 'Red (Deluxe Edition)':
        return '2012'
    elif row['album_name'] == '1989 (Deluxe)':
        return '2014'
    elif row['album_name'] == 'reputation':
        return '2017'
    elif row['album_name'] == 'Lover':
        return '2019'
    elif row['album_name'] == 'evermore (deluxe version)':
        return '2020'
    #ok, we know folklore was actually released in Dec 2020, but this will make our analysis easier
    elif row['album_name'] == 'folklore (deluxe version)':
        return '2021'
    #this is slightly differently formatted because the album name is recorded two ways.
    elif 'midnights' in row['album_name']:
        return '2022'
    
    return 'No Date'


# apply the function to the album
## YOUR CODE HERE ##
lyrics['album_year'] = lyrics.apply(album_release, axis = 1)

# inspect the first few rows of the DataFrame
## YOUR CODE HERE ##
lyrics.head()
# Out:
#                     album_name                  track_title  track_n  \
# 0  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 1  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 2  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 3  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 4  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
#
#                                                lyric  line album_year
# 0                    There's something 'bout the way     1       2008
# 1             The street looks when it's just rained     2       2008
# 2  There's a glow off the pavement, you walk me t...     3       2008
# 3  And you know I wanna ask you to dance right there     4       2008
# 4             In the middle of the parking lot, yeah     5       2008

# %% [markdown]
# ### 3. Clean the lyric text
#
# To accurately count keyword mentions, we need to make everything lowercase everything, remove punctuation, and exclude stop words.
#
# * Change everything to lower case and save the result in a new column called `clean_lyric`.
# * Remove punctuation and save the result to the existing `clean_lyric` column.
# * Run the code we provided to remove stopwords.
# * Check to be sure you have what you expect by viewing the first few rows.

# %%
#lowercase
lyrics['clean_lyric'] = lyrics['lyric'].str.lower()

#remove punctuation
lyrics['clean_lyric']= lyrics['clean_lyric'].str.replace('[^\w\s]','')

# %%
#remove stopwords (see the next cell for illustration)
#create a small list of English stop words, feel free to edit this list
stop = ['the', 'a', 'this', 'that', 'to', 'is', 'am', 'was', 'were', 'be', 'being', 'been']


#there are three steps in one here - explained below
#we make a list of words with `.split()`
#then we remove all the words in our list
#then we join the words back together into a string
lyrics['clean_lyric'] = lyrics['clean_lyric'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))

# %%
# inspect the first few rows of the DataFrame
## YOUR CODE HERE ##

# %% [markdown]
# ### The next 4 cells are for illustration only

# %%
#see what `.split()` does
lyrics['clean_lyric_list'] = lyrics['clean_lyric'].apply(lambda x: x.split())
print(lyrics.head())
# Out:
#                     album_name                  track_title  track_n  \
# 0  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 1  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 2  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 3  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 4  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
#
#                                                lyric  line album_year  \
# 0                    There's something 'bout the way     1       2008
# 1             The street looks when it's just rained     2       2008
# 2  There's a glow off the pavement, you walk me t...     3       2008
# 3  And you know I wanna ask you to dance right there     4       2008
# 4             In the middle of the parking lot, yeah     5       2008
#
#                                       clean_lyric  \
# 0                       theres something bout way
# 1               street looks when its just rained
# 2        theres glow off pavement you walk me car
# 3  and you know i wanna ask you dance right there
# 4                   in middle of parking lot yeah
#
#                                     clean_lyric_list
# 0                     [theres, something, bout, way]
# 1           [street, looks, when, its, just, rained]
# 2  [theres, glow, off, pavement, you, walk, me, car]
# 3  [and, you, know, i, wanna, ask, you, dance, ri...
# 4               [in, middle, of, parking, lot, yeah]

# %%
#see what `.join()` does
lyrics['clean_lyric_list_rejoined'] = lyrics['clean_lyric_list'].apply(lambda x: ' '.join(x))
print(lyrics.head())
# Out:
#                     album_name                  track_title  track_n  \
# 0  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 1  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 2  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 3  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 4  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
#
#                                                lyric  line album_year  \
# 0                    There's something 'bout the way     1       2008
# 1             The street looks when it's just rained     2       2008
# 2  There's a glow off the pavement, you walk me t...     3       2008
# 3  And you know I wanna ask you to dance right there     4       2008
# 4             In the middle of the parking lot, yeah     5       2008
#
#                                       clean_lyric  \
# 0                       theres something bout way
# 1               street looks when its just rained
# 2        theres glow off pavement you walk me car
# 3  and you know i wanna ask you dance right there
# 4                   in middle of parking lot yeah
#
#                                     clean_lyric_list  \
# 0                     [theres, something, bout, way]
# 1           [street, looks, when, its, just, rained]
# 2  [theres, glow, off, pavement, you, walk, me, car]
# 3  [and, you, know, i, wanna, ask, you, dance, ri...
# 4               [in, middle, of, parking, lot, yeah]
#
#                         clean_lyric_list_rejoined
# 0                       theres something bout way
# 1               street looks when its just rained
# 2        theres glow off pavement you walk me car
# 3  and you know i wanna ask you dance right there
# 4                   in middle of parking lot yeah

# %%
#remove those illustration columns
lyrics.drop(['clean_lyric_list', 'clean_lyric_list_rejoined'], axis=1, inplace=True)
print(lyrics.head())
# Out:
#                     album_name                  track_title  track_n  \
# 0  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 1  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 2  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 3  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 4  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
#
#                                                lyric  line album_year  \
# 0                    There's something 'bout the way     1       2008
# 1             The street looks when it's just rained     2       2008
# 2  There's a glow off the pavement, you walk me t...     3       2008
# 3  And you know I wanna ask you to dance right there     4       2008
# 4             In the middle of the parking lot, yeah     5       2008
#
#                                       clean_lyric
# 0                       theres something bout way
# 1               street looks when its just rained
# 2        theres glow off pavement you walk me car
# 3  and you know i wanna ask you dance right there
# 4                   in middle of parking lot yeah

# %%
#there are many pre-built lists of stopwords, including one from sklearn.
#Most exclude too many words to be appropriate for song lyric analysis.
from sklearn.feature_extraction import text
skl_stop = text.ENGLISH_STOP_WORDS
print(skl_stop)
# Out:
# frozenset({'more', 'through', 'move', 'otherwise', 'except', 'whoever', 'becomes', 'yourself', 'bill', 'former', 'namely', 'each', 'which', 'who', 'moreover', 'might', 'sometime', 'ie', 'throughout', 'couldnt', 'find', 'sincere', 'these', 'fifty', 'itself', 'four', 'else', 'at', 'am', 'hundred', 'everyone', 'forty', 'give', 'on', 'already', 'found', 'himself', 'yet', 'such', 'full', 'seemed', 'mine', 'wherein', 'done', 'hers', 'less', 'go', 'along', 'there', 'from', 'we', 'other', 'sixty', 'made', 'take', 'ourselves', 'so', 'whether', 'without', 'and', 'her', 'some', 'due', 'describe', 'my', 'un', 'toward', 'side', 'cry', 'sometimes', 'our', 'much', 'anything', 'detail', 'whole', 'everywhere', 'them', 'cannot', 'they', 'top', 'been', 'six', 'thick', 'during', 'with', 'onto', 'nor', 'was', 'herein', 'than', 'into', 'above', 'against', 'even', 'seems', 'get', 'anywhere', 'between', 'have', 'several', 'down', 'de', 'about', 'although', 'inc', 'three', 'thereafter', 'also', 'until', 'fifteen', 'you', 'name', 'con', 'rather', 'among', 'by', 'across', 'he', 'noone', 'amoungst', 'fill', 'is', 'often', 'whatever', 'thus', 'that', 'she', 'per', 'never', 'whereupon', 'well', 'may', 'before', 'indeed', 'both', 'few', 'hence', 'etc', 'ten', 'somewhere', 'or', 'must', 'upon', 'its', 'eight', 'your', 'whither', 'anyone', 'why', 'yours', 'thereby', 'amongst', 'either', 'towards', 'keep', 'together', 'co', 'amount', 'not', 'part', 'around', 'same', 'here', 'empty', 'though', 'whose', 'many', 'bottom', 'will', 'third', 'up', 'thereupon', 'become', 'seeming', 'another', 'beside', 'mill', 'nobody', 'see', 'thin', 'do', 'first', 'besides', 'anyway', 'nothing', 'out', 'of', 'nine', 'me', 'nevertheless', 'neither', 'front', 'everything', 'therefore', 'a', 'becoming', 'off', 'too', 'under', 'what', 'five', 'how', 'interest', 'herself', 'him', 'twelve', 'formerly', 're', 'anyhow', 'as', 'call', 'perhaps', 'thru', 'meanwhile', 'however', 'afterwards', 'wherever', 'while', 'own', 'should', 'very', 'almost', 'eg', 'after', 'therein', 'are', 'but', 'fire', 'over', 'put', 'further', 'has', 'themselves', 'elsewhere', 'hereafter', 'cant', 'yourselves', 'via', 'whereas', 'eleven', 'mostly', 'below', 'latter', 'since', 'hasnt', 'least', 'i', 'beforehand', 'back', 'nowhere', 'whereby', 'seem', 'hereby', 'one', 'could', 'had', 'someone', 'can', 'ltd', 'their', 'when', 'in', 'whenever', 'the', 'within', 'would', 'always', 'no', 'were', 'whence', 'if', 'became', 'latterly', 'system', 'most', 'next', 'myself', 'those', 'where', 'none', 'every', 'us', 'still', 'others', 'only', 'show', 'hereupon', 'last', 'serious', 'something', 'somehow', 'whereafter', 'whom', 'all', 'an', 'be', 'once', 'then', 'beyond', 'behind', 'ours', 'enough', 'it', 'again', 'for', 'being', 'two', 'because', 'his', 'ever', 'this', 'now', 'please', 'twenty', 'thence', 'alone', 'any', 'to'})

# %% [markdown]
# ### 4. Find keyword mentions
#
# Because we are most interested in "midnight", we will first count how many times midnight occurs in Taylor Swift's lyrics.
#
# * Create a new column to indicate if a lyric has "midnight" in it.
# * Check how many times midnight occurrs

# %%
#create a new column to reflect if the lyrics contain midnight
## YOUR CODE HERE ##
lyrics['midnight'] = lyrics['clean_lyric'].str.contains('midnight')
sum(lyrics['midnight'])
# Out:
# 9

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover in this step? Toggle to check!</i></summary>
#
# Midnight is not very common -- it only appeared 9 times!
#
# </details>

# %% [markdown]
# ### 5. Expand the keyword list
#
# Midnight might not be the only way that Taylor Swift has talked about night. We need to expand our list. We've made a list of night words and day words. Feel free to add or remove words to make the list your own.
#
# * Join the lists into a regular expression string using the `.join()` function and the `|` to indicate "or"
# * Create a new column for each word category (day, night, time) that evaluates the clean lyrics for the presence of the words in your regular expression.
# * Count how many times the words appeared and print the result to the screen
# * Inspect the first few rows of the lyrics DataFrame to be sure it looks as you expect

# %%
#night, day, and other time-related words
night = ['night','midnight', 'dawn', 'dusk', 'evening', 'late', 'dark', '1am', '2am', '3am', '4am']
day = ['day', 'morning', 'light', 'sun', 'dawn', 'noon', 'golden', 'bright']
time = ['today', 'tomorrow', 'yesterday']

# %%
#create a regular expression string for each list of words
night_regex = '|'.join(night)
day_regex = '|'.join(day)
time_regex = '|'.join(time)

#create a new column for each category of words
lyrics['night'] = lyrics['clean_lyric'].str.contains(night_regex)
lyrics['day'] = lyrics['clean_lyric'].str.contains(day_regex)
lyrics['time'] = lyrics['clean_lyric'].str.contains(time_regex)

#count the number of times each category of word appears in the lyrics
night_count = sum(lyrics['night'])
day_count = sum(lyrics['day'])
time_count = sum(lyrics['time'])

#print the count of each word category
print("night words: ", night_count)
print("day words: ", day_count)
print("time words: ", time_count)

#inspect the first few rows
lyrics.head()
# Out:
# night words:  240
# day words:  363
# time words:  35
#                     album_name                  track_title  track_n  \
# 0  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 1  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 2  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 3  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 4  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
#
#                                                lyric  line album_year  \
# 0                    There's something 'bout the way     1       2008
# 1             The street looks when it's just rained     2       2008
# 2  There's a glow off the pavement, you walk me t...     3       2008
# 3  And you know I wanna ask you to dance right there     4       2008
# 4             In the middle of the parking lot, yeah     5       2008
#
#                                       clean_lyric  midnight  night    day  \
# 0                       theres something bout way     False  False  False
# 1               street looks when its just rained     False  False  False
# 2        theres glow off pavement you walk me car     False  False  False
# 3  and you know i wanna ask you dance right there     False  False  False
# 4                   in middle of parking lot yeah     False  False  False
#
#     time
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False

# %%
#inspect the first few rows
## YOUR CODE HERE ##

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover in this step? Toggle to check!</i></summary>
#
# Taylor Swift has referenced time alot, there's enough mentions for us to potentially spot some trends. Also, she has mentioned day far more than night. This might be because of the search terms, so we might consider revisiting the list. Or it could be because she is actually more focused on day and light than she is on night and dark.
#
# </details>

# %% [markdown]
# # Task Group 2

# %% [markdown]
# ### 6. Visualize how Taylor Swift's mentions of time have changed over time.
#
# Now that we know that she has referenced time, we can see if that has changed, and if she has been dropping any hints about her upcoming album.
# * Create a new dataframe called `yearly_mentions` that groups her mentions by year, and takes the sum of the other columns. Reset the index on this DataFrame to make it easier to use with matplotlib
# * Create a line chart in matplotlib showing the night mentions over time.

# %%
#create a new dataframe for yearly mentions that groups mentions by year
## YOUR CODE HERE ##
yearly_mentions = lyrics.groupby('album_year').sum().reset_index()
yearly_mentions
# Out:
#   album_year  track_n   line  midnight  night  day  time
# 0       2006     4867  13456         0     19   25     3
# 1       2008    15644  27793         0     42   65    20
# 2       2010     8450  27489         0     31   53     4
# 3       2012    11992  27800         1     48   53     7
# 4       2014     8424  33546         2     27   41     0
# 5       2017     7640  33775         3     25   25     0
# 6       2019     8813  25741         0     22   46     0
# 7       2020     8443  25712         2     18   38     0
# 8       2021     6193  16854         1      8   17     1

# %%
#plot the mentions of night over years
## YOUR CODE HERE ##
plt.plot(yearly_mentions['album_year'], yearly_mentions['night'], label = 'Night')
plt.legend()
plt.show()

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover in this step? Toggle to check!</i></summary>
#
# It looks like there was a peak in her mentioning night around 2012. It seems like those mentions have become less prevalent over time, with an actual dip in 2019! We had expected midnight to appear more often around then, based on rumors that she plans everything 3 years out.
#
# </details>

# %% [markdown]
# ### 7. What albums are the most night/day focused?
# Now that we have a table of counts, it's very easy to figure out which albums have the most mentions of day or night. But our DataFrame only has the years, not the album names. We need to add those back in.
# * Run the code that reinstates the album name for this dataframe.
# * Use `.sort_values()` to order the yearly_mentions table and find which year has the most mentions of night.
# * Sort the day column as well.

# %%
#reinstate the album name
#read the album_year_name.csv
year_name = pd.read_csv('album_year_name.csv')

#sort both dataframes by year
yearly_mentions.sort_values(by='album_year', ascending=True, inplace=True)
year_name.sort_values(by='album_year', ascending=True, inplace=True)

#add the new column for album name
yearly_mentions['album_name'] = year_name['album_name']

# %%
#sort the lyrics by the night column to find the albums with the most night references
## YOUR CODE HERE ##
yearly_mentions.sort_values(by='night', ascending=False)
# Out:
#   album_year  track_n   line  midnight  night  day  time
# 3       2012    11992  27800         1     48   53     7
# 1       2008    15644  27793         0     42   65    20
# 2       2010     8450  27489         0     31   53     4
# 4       2014     8424  33546         2     27   41     0
# 5       2017     7640  33775         3     25   25     0
# 6       2019     8813  25741         0     22   46     0
# 0       2006     4867  13456         0     19   25     3
# 7       2020     8443  25712         2     18   38     0
# 8       2021     6193  16854         1      8   17     1

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover in this step? Toggle to check!</i></summary>
#
# Her most "nightly" album was reputation in 2012, whereas her least nightly album was also the one right before Midnight. Has she been saving all her night-related lyrics for the past 3 years?
#
# </details>

# %%
#sort the lyrics by the day column to find the albums with the most day references
## YOUR CODE HERE ##
yearly_mentions.sort_values(by='day', ascending=False)
# Out:
#   album_year  track_n   line  midnight  night  day  time
# 1       2008    15644  27793         0     42   65    20
# 2       2010     8450  27489         0     31   53     4
# 3       2012    11992  27800         1     48   53     7
# 6       2019     8813  25741         0     22   46     0
# 4       2014     8424  33546         2     27   41     0
# 7       2020     8443  25712         2     18   38     0
# 0       2006     4867  13456         0     19   25     3
# 5       2017     7640  33775         3     25   25     0
# 8       2021     6193  16854         1      8   17     1

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover in this step? Toggle to check!</i></summary>
#
# It seems like her older work focused on day much more than her more recent. There was a period of time (2008-2012) when she was really focused on day, but it seems to have become less central to her work more recently.
#
# </details>

# %% [markdown]
# ### 8. Compare day to night mentions
# * Create another line chart with both the night mentions and the day mentions

# %%
#create a plot with one line showing number of night references by year 
#and another line with the number of day references by year
## YOUR CODE HERE ##
plt.plot(yearly_mentions['album_year'], yearly_mentions['night'], label = 'night')
plt.plot(yearly_mentions['album_year'], yearly_mentions['day'], label = 'day')
plt.legend()
plt.show()

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover in this step? Toggle to check!</i></summary>
#
# Well this is interesting. We see a similar dip in referencing time around 2017, but a sharp increase in both 2019 and 2020 to reference day.
#
# </details>

# %% [markdown]
# ### 9. Investigate position of day vs. night mentions within albums
# Maybe her references to time aren't always about the year that she released the album, but the ebb and flow of the album itself. Let's plot where, within each album, references to day and night occur.
#
# * Create a variable that indicates the position of a lyric within an album. Call this 'position'.
# * Create a new dataframe called positional_mentions that groups her mentions by album position, and takes the sum of the other columns. Reset the index on this DataFrame to make it easier to use with matplotlib.
# * Create a line chart in matplotlib showing the night and day mentions as a position within the album.
#
# *Remember that you can always print the head of the DataFrame to check your work*

# %%
#create a position variable that includes both the track number and line number
## YOUR CODE HERE ##
lyrics['position'] = lyrics['track_n'] + (lyrics['line']/1000)
#create a new DataFrame that is grouped by position
## YOUR CODE HERE ##
positional_mentions = lyrics.groupby('position').sum().reset_index()

# %%
#increase the size of the plot 
fig = plt.gcf()
fig.set_size_inches(6,2)

#create a plot with two lines to show frequency of day vs. night references by position in the album
## YOUR CODE HERE ##
plt.plot(positional_mentions['position'], positional_mentions['day'], label = 'day')
plt.plot(positional_mentions['position'], positional_mentions['night'], label = 'day')
plt.legend()
plt.show()

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover in this step? Toggle to check!</i></summary>
#
#     Honestly not that much -- we can't see any strong trends here. Best to move on.
# </details>

# %% [markdown]
# # Task Group 3

# %% [markdown]
# ### 10. Tokenize the Lyrics
# It's great to know how much she has focused on day and night, but we would also like to do a little more sophisticated analysis. Before we can work with our cleaned lyrics, we will have to tokenize them. Tokenization is a special way of breaking up words that is a little more nuanced than just using white space. The output is a list of words that we can then perform text analysis on.
#
# We will use the `word_tokenize` function from NLTK (the Natural Language ToolKit), and apply it to every row in our DataFrame with a lambda expression.
#
# * Run the cell to tokenize the cleaned lyrics.
# * Inspect the first few rows of the lyrics DataFrame
# * Create a list of all the tokens in the lyrics_tok column into one list
# * Use the Counter function from the collections package to count the number of times each word appears
# * Sort the resulting dictionary

# %%
#run this cell to tokenize the words in the clean_lyric column
lyrics['lyrics_tok'] = lyrics['clean_lyric'].str.split(' ')

# %%
#inspect the first few lines
## YOUR CODE HERE ##
lyrics.head()
# Out:
#                     album_name                  track_title  track_n  \
# 0  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 1  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 2  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 3  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 4  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
#
#                                                lyric  line album_year  \
# 0                    There's something 'bout the way     1       2008
# 1             The street looks when it's just rained     2       2008
# 2  There's a glow off the pavement, you walk me t...     3       2008
# 3  And you know I wanna ask you to dance right there     4       2008
# 4             In the middle of the parking lot, yeah     5       2008
#
#                                       clean_lyric  midnight  night    day  \
# 0                       theres something bout way     False  False  False
# 1               street looks when its just rained     False  False  False
# 2        theres glow off pavement you walk me car     False  False  False
# 3  and you know i wanna ask you dance right there     False  False  False
# 4                   in middle of parking lot yeah     False  False  False
#
#     time  position                                         lyrics_tok
# 0  False     1.001                     [theres, something, bout, way]
# 1  False     1.002           [street, looks, when, its, just, rained]
# 2  False     1.003  [theres, glow, off, pavement, you, walk, me, car]
# 3  False     1.004  [and, you, know, i, wanna, ask, you, dance, ri...
# 4  False     1.005               [in, middle, of, parking, lot, yeah]

# %%
#determine what words overall are the most frequently used words
#create a list of all the words in the lyrics_tok column
word_list = [word for list_ in lyrics['lyrics_tok'] for word in list_]

#use the counter function to count the number of times each word appears
## YOUR CODE HERE ##
word_frequency = collections.Counter(word_list)

#sort the word frequencies to find out the most common words she's used. 
## YOUR CODE HERE ##
word_frequency = sorted(word_frequency.items(), key = lambda x:x[1], reverse= True)
#call the word frequency
## YOUR CODE HERE ##
word_frequency
# Out:
# [('you', 2835),
#  ('i', 2635),
#  ('and', 1712),
#  ('me', 1063),
#  ('it', 931),
#  ('in', 887),
#  ('my', 816),
#  ('your', 623),
#  ('of', 592),
#  ('but', 540),
#  ('all', 531),
#  ('im', 501),
#  ('we', 498),
#  ('like', 488),
#  ('on', 467),
#  ('know', 456),
#  ('so', 422),
#  ('oh', 411),
#  ('dont', 406),
#  ('when', 392),
#  ('its', 380),
#  ('never', 353),
#  ('youre', 343),
#  ('just', 339),
#  ('for', 306),
#  ('now', 305),
#  ('with', 302),
#  ('love', 295),
#  ('what', 284),
#  ('up', 272),
#  ('out', 270),
#  ('back', 267),
#  ('time', 261),
#  ('cause', 253),
#  ('at', 249),
#  ('if', 245),
#  ('are', 225),
#  ('no', 213),
#  ('one', 201),
#  ('got', 201),
#  ('see', 199),
#  ('say', 198),
#  ('do', 195),
#  ('think', 192),
#  ('baby', 188),
#  ('down', 181),
#  ('want', 181),
#  ('go', 181),
#  ('they', 173),
#  ('come', 172),
#  ('could', 167),
#  ('can', 164),
#  ('there', 162),
#  ('not', 162),
#  ('wanna', 161),
#  ('cant', 157),
#  ('ill', 156),
#  ('right', 155),
#  ('said', 146),
#  ('have', 146),
#  ('yeah', 145),
#  ('he', 144),
#  ('ever', 140),
#  ('would', 140),
#  ('had', 134),
#  ('look', 133),
#  ('thats', 133),
#  ('get', 127),
#  ('how', 122),
#  ('stay', 122),
#  ('here', 121),
#  ('take', 119),
#  ('id', 119),
#  ('way', 117),
#  ('ive', 116),
#  ('tell', 115),
#  ('night', 114),
#  ('still', 113),
#  ('about', 112),
#  ('gonna', 110),
#  ('home', 110),
#  ('as', 108),
#  ('off', 104),
#  ('did', 102),
#  ('made', 102),
#  ('good', 102),
#  ('ooh', 101),
#  ('why', 100),
#  ('from', 98),
#  ('too', 98),
#  ('ohoh', 97),
#  ('feel', 96),
#  ('around', 95),
#  ('everything', 93),
#  ('bad', 93),
#  ('better', 90),
#  ('then', 90),
#  ('things', 90),
#  ('our', 90),
#  ('didnt', 89),
#  ('away', 88),
#  ('only', 86),
#  ('call', 85),
#  ('through', 84),
#  ('wish', 84),
#  ('girl', 84),
#  ('again', 84),
#  ('new', 83),
#  ('eyes', 82),
#  ('shake', 81),
#  ('let', 81),
#  ('long', 81),
#  ('knew', 79),
#  ('every', 79),
#  ('him', 78),
#  ('who', 76),
#  ('red', 76),
#  ('first', 75),
#  ('ah', 75),
#  ('well', 74),
#  ('will', 74),
#  ('youll', 73),
#  ('name', 73),
#  ('eh', 73),
#  ('last', 72),
#  ('yet', 71),
#  ('little', 70),
#  ('make', 70),
#  ('by', 70),
#  ('thing', 70),
#  ('she', 69),
#  ('nothing', 68),
#  ('forever', 67),
#  ('where', 66),
#  ('hes', 65),
#  ('life', 64),
#  ('hey', 64),
#  ('best', 63),
#  ('keep', 62),
#  ('us', 62),
#  ('break', 62),
#  ('face', 61),
#  ('or', 61),
#  ('leave', 61),
#  ('heart', 61),
#  ('day', 60),
#  ('lights', 60),
#  ('alone', 59),
#  ('even', 59),
#  ('mind', 58),
#  ('always', 58),
#  ('gone', 58),
#  ('need', 57),
#  ('theres', 56),
#  ('remember', 56),
#  ('his', 55),
#  ('waiting', 55),
#  ('into', 55),
#  ('something', 54),
#  ('should', 54),
#  ('smile', 54),
#  ('man', 54),
#  ('before', 52),
#  ('thought', 52),
#  ('beautiful', 52),
#  ('over', 52),
#  ('car', 51),
#  ('isnt', 51),
#  ('dancing', 51),
#  ('knows', 50),
#  ('aint', 49),
#  ('some', 49),
#  ('whoa', 49),
#  ('hands', 48),
#  ('friends', 48),
#  ('find', 48),
#  ('an', 48),
#  ('hope', 48),
#  ('wont', 48),
#  ('mad', 48),
#  ('mine', 47),
#  ('hold', 47),
#  ('head', 46),
#  ('walk', 45),
#  ('fall', 45),
#  ('lost', 45),
#  ('shes', 45),
#  ('door', 45),
#  ('end', 45),
#  ('wrong', 45),
#  ('run', 44),
#  ('hand', 44),
#  ('put', 44),
#  ('coming', 44),
#  ('feeling', 44),
#  ('her', 44),
#  ('mean', 44),
#  ('hate', 44),
#  ('left', 43),
#  ('once', 43),
#  ('sorry', 42),
#  ('clear', 42),
#  ('light', 41),
#  ('miss', 41),
#  ('much', 41),
#  ('place', 41),
#  ('trying', 40),
#  ('them', 40),
#  ('talk', 40),
#  ('youve', 40),
#  ('old', 40),
#  ('daylight', 40),
#  ('than', 39),
#  ('enough', 39),
#  ('room', 39),
#  ('saw', 39),
#  ('took', 39),
#  ('dress', 38),
#  ('dreams', 38),
#  ('hear', 38),
#  ('watch', 38),
#  ('follow', 38),
#  ('york', 38),
#  ('meet', 38),
#  ('everybody', 38),
#  ('woods', 38),
#  ('town', 37),
#  ('really', 37),
#  ('whole', 37),
#  ('play', 37),
#  ('dark', 37),
#  ('met', 36),
#  ('rain', 36),
#  ('world', 36),
#  ('these', 36),
#  ('live', 36),
#  ('street', 35),
#  ('kiss', 35),
#  ('give', 35),
#  ('known', 35),
#  ('their', 35),
#  ('ha', 35),
#  ('other', 34),
#  ('people', 34),
#  ('together', 34),
#  ('goes', 34),
#  ('blue', 34),
#  ('gave', 33),
#  ('forget', 33),
#  ('big', 33),
#  ('asking', 33),
#  ('nice', 33),
#  ('shouldve', 33),
#  ('more', 32),
#  ('song', 32),
#  ('has', 32),
#  ('used', 32),
#  ('welcome', 32),
#  ('trouble', 32),
#  ('darling', 32),
#  ('wanted', 31),
#  ('anything', 31),
#  ('yes', 31),
#  ('same', 31),
#  ('fight', 31),
#  ('phone', 31),
#  ('youd', 31),
#  ('game', 31),
#  ('lose', 31),
#  ('those', 30),
#  ('else', 30),
#  ('loved', 30),
#  ('wait', 30),
#  ('getting', 30),
#  ('another', 30),
#  ('meaning', 30),
#  ('hard', 29),
#  ('please', 29),
#  ('help', 29),
#  ('myself', 29),
#  ('silence', 29),
#  ('today', 29),
#  ('turn', 29),
#  ('touch', 29),
#  ('official', 29),
#  ('lyrics', 29),
#  ('verified', 29),
#  ('late', 28),
#  ('side', 28),
#  ('heard', 28),
#  ('times', 28),
#  ('mr', 28),
#  ('drive', 27),
#  ('believe', 27),
#  ('soon', 27),
#  ('found', 27),
#  ('went', 27),
#  ('looking', 27),
#  ('without', 27),
#  ('breathe', 27),
#  ('show', 27),
#  ('wed', 27),
#  ('fly', 27),
#  ('true', 27),
#  ('fake', 27),
#  ('soul', 27),
#  ('body', 27),
#  ('til', 26),
#  ('try', 26),
#  ('might', 26),
#  ('standing', 26),
#  ('change', 26),
#  ('high', 26),
#  ('honey', 26),
#  ('weve', 26),
#  ('bye', 26),
#  ('joeboy', 26),
#  ('sip', 26),
#  ('alcohol', 26),
#  ('someday', 25),
#  ('story', 25),
#  ('dead', 25),
#  ('save', 25),
#  ('fine', 25),
#  ('friend', 25),
#  ('rains', 25),
#  ('came', 25),
#  ('places', 25),
#  ('grow', 25),
#  ('seen', 24),
#  ('years', 24),
#  ('boy', 24),
#  ('after', 24),
#  ('far', 24),
#  ('front', 24),
#  ('fun', 24),
#  ('dance', 23),
#  ('makes', 23),
#  ('ground', 23),
#  ('shine', 23),
#  ('many', 23),
#  ('happy', 23),
#  ('anymore', 23),
#  ('couldnt', 23),
#  ('crazy', 23),
#  ('eye', 23),
#  ('jump', 23),
#  ('dream', 23),
#  ('alright', 23),
#  ('wishing', 23),
#  ('cool', 22),
#  ('summer', 22),
#  ('since', 22),
#  ('sometimes', 22),
#  ('sad', 22),
#  ('okay', 22),
#  ('must', 22),
#  ('guess', 22),
#  ('lips', 22),
#  ('starlight', 22),
#  ('stop', 22),
#  ('getaway', 22),
#  ('looks', 21),
#  ('very', 21),
#  ('both', 21),
#  ('young', 21),
#  ('window', 21),
#  ('thinking', 21),
#  ('wouldve', 21),
#  ('past', 21),
#  ('picture', 21),
#  ('burning', 21),
#  ('tied', 21),
#  ('moment', 20),
#  ('somebody', 20),
#  ('walked', 20),
#  ('nobody', 20),
#  ('days', 20),
#  ('walking', 20),
#  ('house', 20),
#  ('stand', 20),
#  ('morning', 20),
#  ('words', 20),
#  ('games', 20),
#  ('em', 20),
#  ('pain', 20),
#  ('gotta', 20),
#  ('theyll', 20),
#  ('died', 20),
#  ('bout', 19),
#  ('middle', 19),
#  ('road', 19),
#  ('hair', 19),
#  ('close', 19),
#  ('cold', 19),
#  ('fairytale', 19),
#  ('maybe', 19),
#  ('kind', 19),
#  ('clean', 19),
#  ('told', 19),
#  ('perfectly', 19),
#  ('babe', 19),
#  ('showed', 19),
#  ('blood', 19),
#  ('wonderland', 19),
#  ('ask', 18),
#  ('making', 18),
#  ('gets', 18),
#  ('deep', 18),
#  ('girls', 18),
#  ('real', 18),
#  ('tonight', 18),
#  ('laughing', 18),
#  ('single', 18),
#  ('god', 18),
#  ('finally', 18),
#  ('loving', 18),
#  ('missing', 18),
#  ('yours', 18),
#  ('stood', 17),
#  ('while', 17),
#  ('magic', 17),
#  ('perfect', 17),
#  ('doesnt', 17),
#  ('along', 17),
#  ('easy', 17),
#  ('cut', 17),
#  ('sky', 17),
#  ('pretty', 17),
#  ('because', 17),
#  ('fell', 17),
#  ('stars', 17),
#  ('shame', 17),
#  ('two', 17),
#  ('felt', 17),
#  ('bet', 17),
#  ('read', 17),
#  ('lucky', 17),
#  ('burn', 17),
#  ('begin', 17),
#  ('delicate', 17),
#  ('string', 17),
#  ('la', 17),
#  ('caught', 16),
#  ('begging', 16),
#  ('tired', 16),
#  ('ohohoh', 16),
#  ('someone', 16),
#  ('says', 16),
#  ('almost', 16),
#  ('line', 16),
#  ('beat', 16),
#  ('open', 16),
#  ('held', 16),
#  ('goodbye', 16),
#  ('wasnt', 16),
#  ('feels', 16),
#  ('free', 16),
#  ('own', 16),
#  ('reason', 16),
#  ('city', 16),
#  ('alive', 16),
#  ('gorgeous', 16),
#  ('cornelia', 16),
#  ('next', 15),
#  ('party', 15),
#  ('white', 15),
#  ('belong', 15),
#  ('laugh', 15),
#  ('favorite', 15),
#  ('simple', 15),
#  ('hurt', 15),
#  ('sick', 15),
#  ('heres', 15),
#  ('screaming', 15),
#  ('looked', 15),
#  ('called', 15),
#  ('sure', 15),
#  ('under', 15),
#  ('sun', 15),
#  ('tears', 15),
#  ('die', 15),
#  ('losing', 15),
#  ('running', 15),
#  ('trust', 15),
#  ('list', 15),
#  ('works', 15),
#  ('worse', 15),
#  ('fancy', 15),
#  ('happiness', 15),
#  ('plans', 15),
#  ('bless', 15),
#  ('lot', 14),
#  ('round', 14),
#  ('most', 14),
#  ('crying', 14),
#  ('comes', 14),
#  ('stupid', 14),
#  ('feet', 14),
#  ('doing', 14),
#  ('ending', 14),
#  ('doin', 14),
#  ('couldve', 14),
#  ('each', 14),
#  ('bright', 14),
#  ('taking', 14),
#  ('sing', 14),
#  ('saying', 14),
#  ('whos', 14),
#  ('worth', 14),
#  ('black', 14),
#  ('whenever', 14),
#  ('worst', 14),
#  ('treacherous', 14),
#  ('bed', 14),
#  ('does', 14),
#  ('whats', 14),
#  ('memories', 14),
#  ('anywhere', 14),
#  ('breath', 13),
#  ('wondering', 13),
#  ('wake', 13),
#  ('cry', 13),
#  ('work', 13),
#  ('watched', 13),
#  ('undone', 13),
#  ('speak', 13),
#  ('school', 13),
#  ('outside', 13),
#  ('learned', 13),
#  ('apart', 13),
#  ('rest', 13),
#  ('wouldnt', 13),
#  ('pretend', 13),
#  ('signs', 13),
#  ('golden', 13),
#  ('moved', 13),
#  ('anyone', 13),
#  ('nights', 13),
#  ('22', 13),
#  ('problems', 13),
#  ('loves', 13),
#  ('bought', 13),
#  ('drunk', 13),
#  ('december', 13),
#  ('hit', 13),
#  ('turned', 13),
#  ('sitting', 13),
#  ('behind', 13),
#  ('oohoohoohooh', 13),
#  ('boys', 12),
#  ('fifteen', 12),
#  ('sit', 12),
#  ('theyre', 12),
#  ('changed', 12),
#  ('talking', 12),
#  ('catch', 12),
#  ('step', 12),
#  ('fighting', 12),
#  ('rush', 12),
#  ('wild', 12),
#  ('low', 12),
#  ('gold', 12),
#  ('until', 12),
#  ('paint', 12),
#  ('walls', 12),
#  ('win', 12),
#  ('million', 12),
#  ('sleep', 12),
#  ('gray', 12),
#  ('takes', 12),
#  ('burned', 12),
#  ('cruel', 12),
#  ('fast', 12),
#  ('busy', 12),
#  ('fire', 12),
#  ('quite', 12),
#  ('funny', 12),
#  ('any', 12),
#  ('heartbreak', 12),
#  ('though', 12),
#  ('reputation', 12),
#  ('usin', 12),
#  ('floor', 12),
#  ('oohah', 12),
#  ('wonder', 11),
#  ('slow', 11),
#  ('havent', 11),
#  ('ends', 11),
#  ('flashback', 11),
#  ('starts', 11),
#  ('air', 11),
#  ('pulled', 11),
#  ('write', 11),
#  ('going', 11),
#  ('killing', 11),
#  ('inside', 11),
#  ('insane', 11),
#  ('seems', 11),
#  ('hide', 11),
#  ('scared', 11),
#  ('throw', 11),
#  ('hang', 11),
#  ('invisible', 11),
#  ('tryna', 11),
#  ('broke', 11),
#  ('water', 11),
#  ('daydream', 11),
#  ('blame', 11),
#  ('singing', 11),
#  ('promise', 11),
#  ('paper', 11),
#  ('lets', 11),
#  ('green', 11),
#  ('marvelous', 11),
#  ('ya', 11),
#  ('style', 11),
#  ('sign', 11),
#  ('damn', 11),
#  ('word', 11),
#  ('ready', 11),
#  ('passed', 11),
#  ('drug', 11),
#  ('woman', 11),
#  ('sparks', 11),
#  ('uh', 11),
#  ('brave', 10),
#  ('cried', 10),
#  ('hello', 10),
#  ('mess', 10),
#  ('mmmm', 10),
#  ('brought', 10),
#  ('giving', 10),
#  ('taken', 10),
#  ('figured', 10),
#  ('hearts', 10),
#  ('cuts', 10),
#  ('three', 10),
#  ('heaven', 10),
#  ('everyone', 10),
#  ('arms', 10),
#  ('strong', 10),
#  ('spinning', 10),
#  ('slope', 10),
#  ('lying', 10),
#  ('falling', 10),
#  ('scene', 10),
#  ('lord', 10),
#  ('lover', 10),
#  ('months', 10),
#  ('blind', 10),
#  ('started', 10),
#  ('wildest', 10),
#  ('ateam', 10),
#  ('whys', 10),
#  ('turns', 10),
#  ('american', 10),
#  ('wine', 10),
#  ('nobodys', 10),
#  ('forgot', 10),
#  ('worship', 10),
#  ('prove', 10),
#  ('closure', 10),
#  ('fearless', 9),
#  ('yourself', 9),
#  ('garden', 9),
#  ('afraid', 9),
#  ('faith', 9),
#  ('half', 9),
#  ('lead', 9),
#  ('small', 9),
#  ('chance', 9),
#  ('short', 9),
#  ('movie', 9),
#  ('2', 9),
#  ('heartbeat', 9),
#  ('breaking', 9),
#  ('warning', 9),
#  ('drop', 9),
#  ('move', 9),
#  ('threw', 9),
#  ('mistakes', 9),
#  ('broken', 9),
#  ('grace', 9),
#  ('fate', 9),
#  ('uhuh', 9),
#  ('swear', 9),
#  ('peace', 9),
#  ('stayed', 9),
#  ('page', 9),
#  ('understand', 9),
#  ('pouring', 9),
#  ('dressed', 9),
#  ('london', 9),
#  ('ahah', 9),
#  ('loud', 9),
#  ('rumors', 9),
#  ('less', 9),
#  ('shaking', 9),
#  ('pictures', 9),
#  ('covered', 9),
#  ('calm', 9),
#  ('shit', 9),
#  ('radidididididididididada', 9),
#  ('bar', 9),
#  ('champagne', 9),
#  ('shined', 9),
#  ('truck', 9),
#  ('drew', 9),
#  ('rings', 9),
#  ('death', 9),
#  ('evermore', 9),
#  ('storm', 8),
#  ('somewhere', 8),
#  ('quiet', 8),
#  ('letter', 8),
#  ('mmm', 8),
#  ('wear', 8),
#  ('dreaming', 8),
#  ('jeans', 8),
#  ('heels', 8),
#  ('playing', 8),
#  ('bring', 8),
#  ('tried', 8),
#  ('innocent', 8),
#  ('space', 8),
#  ('stare', 8),
#  ('bedroom', 8),
#  ('lives', 8),
#  ('wind', 8),
#  ('scream', 8),
#  ('guitar', 8),
#  ('sweet', 8),
#  ('part', 8),
#  ('such', 8),
#  ('telling', 8),
#  ('flying', 8),
#  ('solve', 8),
#  ('reckless', 8),
#  ('choice', 8),
#  ('bone', 8),
#  ('care', 8),
#  ('flew', 8),
#  ('hell', 8),
#  ('pieces', 8),
#  ('cheeks', 8),
#  ('kid', 8),
#  ('instead', 8),
#  ('sleeping', 8),
#  ('oohoohoohoohooh', 8),
#  ('fears', 8),
#  ('ohho', 8),
#  ('warm', 8),
#  ('train', 8),
#  ('queen', 8),
#  ('money', 8),
#  ('rose', 8),
#  ('tall', 8),
#  ('ones', 8),
#  ('great', 8),
#  ('keeps', 8),
#  ('flames', 8),
#  ('scar', 8),
#  ('king', 8),
#  ('leads', 8),
#  ('mmmmmm', 8),
#  ('spot', 8),
#  ('haah', 8),
#  ('strike', 8),
#  ('waters', 8),
#  ('living', 8),
#  ('haunt', 8),
#  ('film', 8),
#  ('kill', 8),
#  ('thousand', 8),
#  ('wreck', 8),
#  ('dorothea', 8),
#  ('driving', 7),
#  ('seat', 7),
#  ('team', 7),
#  ('marry', 7),
#  ('realized', 7),
#  ('prince', 7),
#  ('ring', 7),
#  ('pick', 7),
#  ('mmmmm', 7),
#  ('rocks', 7),
#  ('holding', 7),
#  ('leaving', 7),
#  ('honestly', 7),
#  ('believed', 7),
#  ('shoulda', 7),
#  ('knees', 7),
#  ('forgiveness', 7),
#  ('shell', 7),
#  ('songs', 7),
#  ('someones', 7),
#  ('hoping', 7),
#  ('cursing', 7),
#  ('talks', 7),
#  ('tight', 7),
#  ('hallelujah', 7),
#  ('faster', 7),
#  ('battle', 7),
#  ('sound', 7),
#  ('spelling', 7),
#  ('start', 7),
#  ('rules', 7),
#  ('wall', 7),
#  ('counting', 7),
#  ('conversation', 7),
#  ('faded', 7),
#  ('stairs', 7),
#  ('shouldnt', 7),
#  ('lived', 7),
#  ('wasted', 7),
#  ('freedom', 7),
#  ('hows', 7),
#  ('above', 7),
#  ('shining', 7),
#  ('iii', 7),
#  ('truth', 7),
#  ('clothes', 7),
#  ('skin', 7),
#  ('hurts', 7),
#  ('headlights', 7),
#  ('few', 7),
#  ('drowning', 7),
#  ('joke', 7),
#  ('somehow', 7),
#  ('ran', 7),
#  ('asked', 7),
#  ('lonely', 7),
#  ('wearing', 7),
#  ('brand', 7),
#  ('spend', 7),
#  ('lipstick', 7),
#  ('players', 7),
#  ('twenty', 7),
#  ('palm', 7),
#  ('whyd', 7),
#  ('shiny', 7),
#  ('whisper', 7),
#  ('older', 7),
#  ('haunted', 7),
#  ('lie', 7),
#  ('twice', 7),
#  ('kingdom', 7),
#  ('actress', 7),
#  ('ridin', 7),
#  ('dying', 7),
#  ('case', 7),
#  ('pay', 7),
#  ('dear', 7),
#  ('roll', 7),
#  ('glass', 7),
#  ('huh', 7),
#  ('ours', 7),
#  ('meee', 7),
#  ('colder', 7),
#  ('superman', 7),
#  ('nothin', 6),
#  ('lalala', 6),
#  ('crowd', 6),
#  ('romeo', 6),
#  ('near', 6),
#  ('reasons', 6),
#  ('forth', 6),
#  ('itll', 6),
#  ('secrets', 6),
#  ('2am', 6),
#  ('happened', 6),
#  ('second', 6),
#  ('hasnt', 6),
#  ('trees', 6),
#  ('names', 6),
#  ('ride', 6),
#  ('smiles', 6),
#  ('wide', 6),
#  ('brighter', 6),
#  ('dim', 6),
#  ('radio', 6),
#  ('comin', 6),
#  ('starin', 6),
#  ('lies', 6),
#  ('amount', 6),
#  ('casually', 6),
#  ('different', 6),
#  ('gate', 6),
#  ('saint', 6),
#  ('colors', 6),
#  ('forgetting', 6),
#  ('impossible', 6),
#  ('midnight', 6),
#  ('given', 6),
#  ('tragic', 6),
#  ('smoke', 6),
#  ('lock', 6),
#  ('strange', 6),
#  ('family', 6),
#  ('motion', 6),
#  ('seem', 6),
#  ('weekend', 6),
#  ('exlovers', 6),
#  ('skies', 6),
#  ('view', 6),
#  ('crashing', 6),
#  ('color', 6),
#  ('pushed', 6),
#  ('least', 6),
#  ('windows', 6),
#  ('hung', 6),
#  ('done', 6),
#  ('scars', 6),
#  ('standin', 6),
#  ('frames', 6),
#  ('sight', 6),
#  ('grown', 6),
#  ('castle', 6),
#  ('romantics', 6),
#  ('dada', 6),
#  ('use', 6),
#  ('cross', 6),
#  ('lovin', 6),
#  ('chill', 6),
#  ('crime', 6),
#  ('secret', 6),
#  ('frozen', 6),
#  ('shape', 6),
#  ('babys', 6),
#  ('tim', 6),
#  ('mcgraw', 6),
#  ('teardrops', 6),
#  ('shade', 6),
#  ('fore', 6),
#  ('hallway', 6),
#  ('waves', 6),
#  ('august', 6),
#  ('likes', 6),
#  ('daughter', 6),
#  ('existed', 6),
#  ('wants', 6),
#  ('1', 6),
#  ('hometown', 6),
#  ('false', 6),
#  ('goddamn', 6),
#  ('stone', 6),
#  ('enchanted', 6),
#  ('drag', 5),
#  ('flawless', 5),
#  ('thinkin', 5),
#  ('dancin', 5),
#  ('swore', 5),
#  ('bigger', 5),
#  ('supposed', 5),
#  ('princess', 5),
#  ('stephen', 5),
#  ('tossing', 5),
#  ('angel', 5),
#  ('tuesday', 5),
#  ('music', 5),
#  ('understands', 5),
#  ('streets', 5),
#  ('none', 5),
#  ('minds', 5),
#  ('tragedy', 5),
#  ('swing', 5),
#  ('attitude', 5),
#  ('hadnt', 5),
#  ('listen', 5),
#  ('father', 5),
#  ('snow', 5),
#  ('grab', 5),
#  ('keys', 5),
#  ('grew', 5),
#  ('ships', 5),
#  ('daddys', 5),
#  ('watching', 5),
#  ('realize', 5),
#  ('waking', 5),
#  ('note', 5),
#  ('played', 5),
#  ('spotlight', 5),
#  ('desperately', 5),
#  ('superstar', 5),
#  ('sayin', 5),
#  ('pride', 5),
#  ('slamming', 5),
#  ('picked', 5),
#  ('wore', 5),
#  ('sense', 5),
#  ('reminds', 5),
#  ('pocket', 5),
#  ('child', 5),
#  ('meant', 5),
#  ('breakin', 5),
#  ('misery', 5),
#  ('porch', 5),
#  ('recall', 5),
#  ('neck', 5),
#  ...]

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover in this step? Toggle to check!</i></summary>
#
#    She mostly talks about you and then herself, while that's not surprising, it also tells us that she's mostly writing about relationships and her realtionships with others.
# </details>

# %% [markdown]
# ### 11. Analyze Lyric Sentiment
#
# To better understand how she thinks and feels about day and night, we want to know which one she writes about more favorably.
#
# We are going to use the pre-trained sentiment classifier that comes with NLTK. It's it trained on tweets and therefore best for short text. It return 4 values: positive, negative, neutral, and compound. Compound will be of special interest to us. It is the normalized sum of positive and negative.
#
# * Run the sample sentiment analyzer cell to see how the SentimentIntensityAnalyzer works.
# * Apply the sia sentiment analyzer to the clean_lyric column of the DataFrame with a lambda expression
# * Run the cell that transforms the dictionary into columns of the DataFrame

# %%
#run this cell to add a package from NLTK for our sentiment analyzer.
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/ccuser/nltk_data...
# True

# %%
#run this cell to see how the sentiment analyzer works
sia = SentimentIntensityAnalyzer()
sia.polarity_scores("I love Taylor Swift!")
# Out:
# {'neg': 0.0, 'neu': 0.137, 'pos': 0.863, 'compound': 0.7424}

# %%
#create a new column called polarity and apply the sia method to the clean_lyric column with a lambda expression
## YOUR CODE HERE ##
lyrics['polarity'] = lyrics['clean_lyric'].apply(lambda x: sia.polarity_scores(x))
lyrics
# Out:
#                        album_name                  track_title  track_n  \
# 0     Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 1     Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 2     Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 3     Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 4     Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# ...                           ...                          ...      ...
# 8353           Speak Now (Deluxe)                     Superman       17
# 8354           Speak Now (Deluxe)                     Superman       17
# 8355           Speak Now (Deluxe)                     Superman       17
# 8356           Speak Now (Deluxe)                     Superman       17
# 8357           Speak Now (Deluxe)                     Superman       17
#
#                                                   lyric  line album_year  \
# 0                       There's something 'bout the way     1       2008
# 1                The street looks when it's just rained     2       2008
# 2     There's a glow off the pavement, you walk me t...     3       2008
# 3     And you know I wanna ask you to dance right there     4       2008
# 4                In the middle of the parking lot, yeah     5       2008
# ...                                                 ...   ...        ...
# 8353                   I'll be right here on the ground    51       2010
# 8354                            When you come back down    52       2010
# 8355                             La, la, la, la, la, la    53       2010
# 8356                             La, la, la, la, la, la    54       2010
# 8357                            When you come back down    55       2010
#
#                                          clean_lyric  midnight  night    day  \
# 0                          theres something bout way     False  False  False
# 1                  street looks when its just rained     False  False  False
# 2           theres glow off pavement you walk me car     False  False  False
# 3     and you know i wanna ask you dance right there     False  False  False
# 4                      in middle of parking lot yeah     False  False  False
# ...                                              ...       ...    ...    ...
# 8353                        ill right here on ground     False  False  False
# 8354                         when you come back down     False  False  False
# 8355                               la la la la la la     False  False  False
# 8356                               la la la la la la     False  False  False
# 8357                         when you come back down     False  False  False
#
#        time  position                                         lyrics_tok  \
# 0     False     1.001                     [theres, something, bout, way]
# 1     False     1.002           [street, looks, when, its, just, rained]
# 2     False     1.003  [theres, glow, off, pavement, you, walk, me, car]
# 3     False     1.004  [and, you, know, i, wanna, ask, you, dance, ri...
# 4     False     1.005               [in, middle, of, parking, lot, yeah]
# ...     ...       ...                                                ...
# 8353  False    17.051                     [ill, right, here, on, ground]
# 8354  False    17.052                      [when, you, come, back, down]
# 8355  False    17.053                           [la, la, la, la, la, la]
# 8356  False    17.054                           [la, la, la, la, la, la]
# 8357  False    17.055                      [when, you, come, back, down]
#
#                                                polarity
# 0     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3     {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4     {'neg': 0.0, 'neu': 0.694, 'pos': 0.306, 'comp...
# ...                                                 ...
# 8353  {'neg': 0.412, 'neu': 0.588, 'pos': 0.0, 'comp...
# 8354  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 8355  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 8356  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 8357  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
#
# [8358 rows x 14 columns]

# %%
#run this cell to transform the polarity dictionary into columns of the DataFrame
lyrics[['neg', 'neu', 'pos', 'compound']] = lyrics['polarity'].apply(pd.Series)
lyrics.drop('polarity', axis=1)
# Out:
#                        album_name                  track_title  track_n  \
# 0     Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 1     Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 2     Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 3     Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 4     Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# ...                           ...                          ...      ...
# 8353           Speak Now (Deluxe)                     Superman       17
# 8354           Speak Now (Deluxe)                     Superman       17
# 8355           Speak Now (Deluxe)                     Superman       17
# 8356           Speak Now (Deluxe)                     Superman       17
# 8357           Speak Now (Deluxe)                     Superman       17
#
#                                                   lyric  line album_year  \
# 0                       There's something 'bout the way     1       2008
# 1                The street looks when it's just rained     2       2008
# 2     There's a glow off the pavement, you walk me t...     3       2008
# 3     And you know I wanna ask you to dance right there     4       2008
# 4                In the middle of the parking lot, yeah     5       2008
# ...                                                 ...   ...        ...
# 8353                   I'll be right here on the ground    51       2010
# 8354                            When you come back down    52       2010
# 8355                             La, la, la, la, la, la    53       2010
# 8356                             La, la, la, la, la, la    54       2010
# 8357                            When you come back down    55       2010
#
#                                          clean_lyric  midnight  night    day  \
# 0                          theres something bout way     False  False  False
# 1                  street looks when its just rained     False  False  False
# 2           theres glow off pavement you walk me car     False  False  False
# 3     and you know i wanna ask you dance right there     False  False  False
# 4                      in middle of parking lot yeah     False  False  False
# ...                                              ...       ...    ...    ...
# 8353                        ill right here on ground     False  False  False
# 8354                         when you come back down     False  False  False
# 8355                               la la la la la la     False  False  False
# 8356                               la la la la la la     False  False  False
# 8357                         when you come back down     False  False  False
#
#        time  position                                         lyrics_tok  \
# 0     False     1.001                     [theres, something, bout, way]
# 1     False     1.002           [street, looks, when, its, just, rained]
# 2     False     1.003  [theres, glow, off, pavement, you, walk, me, car]
# 3     False     1.004  [and, you, know, i, wanna, ask, you, dance, ri...
# 4     False     1.005               [in, middle, of, parking, lot, yeah]
# ...     ...       ...                                                ...
# 8353  False    17.051                     [ill, right, here, on, ground]
# 8354  False    17.052                      [when, you, come, back, down]
# 8355  False    17.053                           [la, la, la, la, la, la]
# 8356  False    17.054                           [la, la, la, la, la, la]
# 8357  False    17.055                      [when, you, come, back, down]
#
#         neg    neu    pos  compound
# 0     0.000  1.000  0.000    0.0000
# 1     0.000  1.000  0.000    0.0000
# 2     0.000  1.000  0.000    0.0000
# 3     0.000  1.000  0.000    0.0000
# 4     0.000  0.694  0.306    0.2960
# ...     ...    ...    ...       ...
# 8353  0.412  0.588  0.000   -0.4215
# 8354  0.000  1.000  0.000    0.0000
# 8355  0.000  1.000  0.000    0.0000
# 8356  0.000  1.000  0.000    0.0000
# 8357  0.000  1.000  0.000    0.0000
#
# [8358 rows x 17 columns]

# %%
#inspect the first few rows
## YOUR CODE HERE ##
lyrics.head()
# Out:
#                     album_name                  track_title  track_n  \
# 0  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 1  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 2  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 3  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 4  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
#
#                                                lyric  line album_year  \
# 0                    There's something 'bout the way     1       2008
# 1             The street looks when it's just rained     2       2008
# 2  There's a glow off the pavement, you walk me t...     3       2008
# 3  And you know I wanna ask you to dance right there     4       2008
# 4             In the middle of the parking lot, yeah     5       2008
#
#                                       clean_lyric  midnight  night    day  \
# 0                       theres something bout way     False  False  False
# 1               street looks when its just rained     False  False  False
# 2        theres glow off pavement you walk me car     False  False  False
# 3  and you know i wanna ask you dance right there     False  False  False
# 4                   in middle of parking lot yeah     False  False  False
#
#     time  position                                         lyrics_tok  \
# 0  False     1.001                     [theres, something, bout, way]
# 1  False     1.002           [street, looks, when, its, just, rained]
# 2  False     1.003  [theres, glow, off, pavement, you, walk, me, car]
# 3  False     1.004  [and, you, know, i, wanna, ask, you, dance, ri...
# 4  False     1.005               [in, middle, of, parking, lot, yeah]
#
#                                             polarity  neg    neu    pos  \
# 0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...  0.0  1.000  0.000
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...  0.0  1.000  0.000
# 2  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...  0.0  1.000  0.000
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...  0.0  1.000  0.000
# 4  {'neg': 0.0, 'neu': 0.694, 'pos': 0.306, 'comp...  0.0  0.694  0.306
#
#    compound
# 0     0.000
# 1     0.000
# 2     0.000
# 3     0.000
# 4     0.296

# %% [markdown]
# ### 12. Corpus Sentiment Analysis
#
# Now that we have sentiment for all of her lyrics, let's learn more about her overall sentiment, as well as how that has change throughout her career.
# * Use the pos, neg, and compound columns to calculate the overall sentiment of her entire collection, and print the result.
# * Use the groupby function and matplotlib to visualize the overall sentiment of her albums over time

# %%
#calculate overall sentiment for pos, neg, sentiment
## YOUR CODE HERE ##
positive = sum(lyrics['pos'])
negative = sum(lyrics['neg'])
neutral = sum(lyrics['neu'])
compound = sum(lyrics['compound'])
#print the overall sentiments
## YOUR CODE HERE ##
print('positive: ', positive)
print('negative: ', negative)
print('neutral: ', neutral)
print('compound: ', compound)
# Out:
# positive:  1102.1670000000026
# negative:  715.9210000000002
# neutral:  6535.9280000000035
# compound:  432.74670000000094

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover in this step? Toggle to check!</i></summary>
#
#    Overall Taylor Swift's lyrics are mostly positive!
# </details>

# %%
#create a new DataFrame using the groupby method for the album_year
## YOUR CODE HERE ##
sentiment = lyrics.groupby('album_year').sum().reset_index()
#visualize sentiment over time 
## YOUR CODE HERE ##
sentiment
# Out:
#   album_year  track_n   line  midnight  night  day  time   position      neg  \
# 0       2006     4867  13456         0     19   25     3   4880.456   45.776
# 1       2008    15644  27793         0     42   65    20  15671.793   88.694
# 2       2010     8450  27489         0     31   53     4   8477.489   78.210
# 3       2012    11992  27800         1     48   53     7  12019.800   89.766
# 4       2014     8424  33546         2     27   41     0   8457.546   90.219
# 5       2017     7640  33775         3     25   25     0   7673.775   76.920
# 6       2019     8813  25741         0     22   46     0   8838.741   77.131
# 7       2020     8443  25712         2     18   38     0   8468.712  104.567
# 8       2021     6193  16854         1      8   17     1   6209.854   64.638
#
#        neu      pos  compound
# 0  484.259   78.964   33.8272
# 1  936.802  144.513   80.4407
# 2  758.679  108.111   29.0617
# 3  825.905  153.329   72.1174
# 4  757.393  158.390   81.1276
# 5  788.665  122.418   38.7202
# 6  707.039  149.832   72.9835
# 7  701.705  105.728    5.7375
# 8  575.481   80.882   18.7309

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover in this step? Toggle to check!</i></summary>
#
#    Her degree of positivity has really fluctuated over time. Her 2020 album was by far the least positive, though all of her albums are actually positive.
# </details>

# %% [markdown]
# ### 13. Day or Night? Positive or Negative
# Finally the big reveal. Does Taylor Swift write more positively about day or night?
# * Create two DataFrames: one for all the lyrics that mention night and one for all the lyrics that mention day.
# * Check that each DataFrame has the right number of values with the `len()` function
# * Calculate the sentiment for both night and day using the compound value and print them.

# %%
#create a DataFrame filtered for only night mentions
## YOUR CODE HERE ##
night_lyrics = lyrics[lyrics['night']==True]
#create a DataFrame filtered for only day mentions
## YOUR CODE HERE ##
day_lyrics = lyrics[lyrics['day']==True]
#print the length of the night and day DataFrames
## YOUR CODE HERE ##
print("night: ",len(night))
print("day: ",len(day))

day_lyrics
# Out:
# night:  11
# day:  8
#                        album_name                     track_title  track_n  \
# 40    Fearless (Taylor’s Version)      Fifteen (Taylor’s Version)        2
# 71    Fearless (Taylor’s Version)      Fifteen (Taylor’s Version)        2
# 86    Fearless (Taylor’s Version)      Fifteen (Taylor’s Version)        2
# 93    Fearless (Taylor’s Version)   Love Story (Taylor’s Version)        3
# 141   Fearless (Taylor’s Version)  Hey Stephen (Taylor’s Version)        4
# ...                           ...                             ...      ...
# 8331           Speak Now (Deluxe)                        Superman       17
# 8334           Speak Now (Deluxe)                        Superman       17
# 8346           Speak Now (Deluxe)                        Superman       17
# 8348           Speak Now (Deluxe)                        Superman       17
# 8352           Speak Now (Deluxe)                        Superman       17
#
#                                                  lyric  line album_year  \
# 40             It's the mornin' of your very first day     2       2008
# 71    Back then, I swore I was gonna marry him someday    33       2008
# 86                                 Your very first day    48       2008
# 93       See the lights, see the party, the ball gowns     5       2008
# 141                    But I know I saw a light in you     5       2008
# ...                                                ...   ...        ...
# 8331                       You've got a busy day today    29       2010
# 8334               Come back, I'll be with you someday    32       2010
# 8346        'Cause I loved you from the very first day    44       2010
# 8348                       You've got a busy day today    46       2010
# 8352                 I swear, I'll be with you someday    50       2010
#
#                                       clean_lyric  midnight  night   day  \
# 40              its mornin of your very first day     False  False  True
# 71    back then i swore i gonna marry him someday     False  False  True
# 86                            your very first day     False  False  True
# 93                see lights see party ball gowns     False  False  True
# 141                 but i know i saw light in you     False  False  True
# ...                                           ...       ...    ...   ...
# 8331                     youve got busy day today     False  False  True
# 8334               come back ill with you someday     False  False  True
# 8346        cause i loved you from very first day     False  False  True
# 8348                     youve got busy day today     False  False  True
# 8352                 i swear ill with you someday     False  False  True
#
#        time  position                                         lyrics_tok  \
# 40    False     2.002          [its, mornin, of, your, very, first, day]
# 71    False     2.033  [back, then, i, swore, i, gonna, marry, him, s...
# 86    False     2.048                           [your, very, first, day]
# 93    False     3.005             [see, lights, see, party, ball, gowns]
# 141   False     4.005             [but, i, know, i, saw, light, in, you]
# ...     ...       ...                                                ...
# 8331   True    17.029                     [youve, got, busy, day, today]
# 8334  False    17.032              [come, back, ill, with, you, someday]
# 8346  False    17.044     [cause, i, loved, you, from, very, first, day]
# 8348   True    17.046                     [youve, got, busy, day, today]
# 8352  False    17.050                [i, swear, ill, with, you, someday]
#
#                                                polarity    neg    neu    pos  \
# 40    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...  0.000  1.000  0.000
# 71    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...  0.000  1.000  0.000
# 86    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...  0.000  1.000  0.000
# 93    {'neg': 0.0, 'neu': 0.649, 'pos': 0.351, 'comp...  0.000  0.649  0.351
# 141   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...  0.000  1.000  0.000
# ...                                                 ...    ...    ...    ...
# 8331  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...  0.000  1.000  0.000
# 8334  {'neg': 0.359, 'neu': 0.641, 'pos': 0.0, 'comp...  0.359  0.641  0.000
# 8346  {'neg': 0.0, 'neu': 0.606, 'pos': 0.394, 'comp...  0.000  0.606  0.394
# 8348  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...  0.000  1.000  0.000
# 8352  {'neg': 0.571, 'neu': 0.429, 'pos': 0.0, 'comp...  0.571  0.429  0.000
#
#       compound
# 40      0.0000
# 71      0.0000
# 86      0.0000
# 93      0.4019
# 141     0.0000
# ...        ...
# 8331    0.0000
# 8334   -0.4215
# 8346    0.5994
# 8348    0.0000
# 8352   -0.4588
#
# [363 rows x 18 columns]

# %%
#calculate the sentiment of each day and night DataFrame from the compound values
## YOUR CODE HERE ##
night_sentiment = night_lyrics['compound'].sum()
day_sentiment = day_lyrics['compound'].sum()
#print the results
## YOUR CODE HERE ##

print("night_sentiment: ", night_sentiment)
print("day_sentiment: ", day_sentiment)
# Out:
# night_sentiment:  17.4022
# day_sentiment:  25.416800000000002

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover in this step? Toggle to check!</i></summary>
#
# She's still overall more positive in her sentiment about day than night!
#
# You have the tools to explore if that sentiment has changed over time, or if her feelings towards night have grown more positive or negative over time. And of course, we would love to see your analysis of her new album, Midnight. Have her feelings changed?
#
# Share your findings in the Codecademy forums!
# </details>
